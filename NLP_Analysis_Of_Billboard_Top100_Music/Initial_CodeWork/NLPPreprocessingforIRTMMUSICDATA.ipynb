# %%
# !pip install pyarrow
# !pip install fastparquet
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 17.9 MB/s
# ...
#      |████████████████████████████████| 136 kB 52.6 MB/s
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-13b0b6bb0a02> in <module>()
#       5 import pandas as pd
#       6
# ----> 7 df=pd.read_parquet('amazon_historical_data.parquet.gzip')
#       8
#       9 df.sort_values('Index',inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     498         storage_options=storage_options,
#     499         use_nullable_dtypes=use_nullable_dtypes,
# --> 500         **kwargs,
#     501     )
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
# ...

# %%
import pyarrow
import fastparquet
import pandas as pd

df=pd.read_parquet('amazon_historical_data.parquet.gzip')

df.sort_values('Index',inplace=True)
df = df.loc[df['Index'] <= 100]
df.to_csv('az.csv',header=True,index=False)
print(df.columns)
print(df.shape)
print(df.head())
print(df.iloc[1][1])
print(df.loc[1]['Review'])
print(type(df.loc[1]['Review']))

# %%
# !pip install mysql-connector-python
# !pip install pymysql
# Out:
# ...
#      |████████████████████████████████| 43 kB 1.9 MB/s
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://admin:DveniTfic1NKHI9HluJ3@project.ccmd1auuwzyh.us-east-1.rds.amazonaws.com/project')

# %%
import pandas as pd
df=pd.read_sql('SELECT * FROM project.BILLBOARD', engine)

# %%
df.head()
# Out:
#                              Artists             Songs  Year  \
# 0                      Daniel Powter           Bad Day  2006
# 1                          Sean Paul       Temperature  2006
# 2  Nelly Furtado Featuring Timbaland       Promiscuous  2006
# 3                        James Blunt  You're Beautiful  2006
# 4      Shakira Featuring Wyclef Jean    Hips Don't Lie  2006
#
#                 Artists_Processed Primary_Artist  \
# 0                   daniel powter  daniel powter
# 1                       sean paul      sean paul
# 2  ['nelly furtado', 'timbaland']  nelly furtado
# 3                 ['james blunt']    james blunt
# 4      ['shakira', 'wyclef jean']        shakira
#
#                                               Lyrics  \
# 0  [<div class="Lyrics__Container-sc-1ynbvzw-6 jY...
# 1  [<div class="Lyrics__Container-sc-1ynbvzw-6 jY...
# 2  [<div class="Lyrics__Container-sc-1ynbvzw-6 jY...
# 3  [<div class="Lyrics__Container-sc-1ynbvzw-6 jY...
# ...

# %%
df.count()
# Out:
# Artists              1598
# Songs                1598
# Year                 1598
# Artists_Processed    1598
# Primary_Artist       1598
# Lyrics               1541
# Genres               1541
# dtype: int64

# %%
# anytext = 'I am trying my hand at NLP'
# anytokens = anytext.split(' ')
# anytokens
# Out:
# ['I', 'am', 'trying', 'my', 'hand', 'at', 'NLP']

# %%
# print(len(anytext))
# print(len(anytokens))
# Out:
# 26
# 7

# %%
# from nltk.c­orpus import brown
# import Corpus­Reader object
brownallwords=brown.w­or­ds(­tex­t_id)
# Returns pretok­enised document as list of words
brownallfileids=brown.f­il­eids()
# Lists docs in Brown corpus
brownallcategories=brown.c­at­ego­ries()
# Lists categories in Brown corpus
# Out:
#   File "<ipython-input-29-55ea53e016ad>", line 3
#     brownallwords=brown.w­or­ds(­tex­t_id)
#                               ^
# SyntaxError: invalid character in identifier
